# %%
#Use this air bnb new york city and remove outliers using percentile based on price per night for a given apartment/home. You can use suitable upper and lower limits on percentile based on your intuition. Your goal is to come up with new pandas dataframe that doesn't have the outliers present in it.

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("E:\Data science\AB_NYC_2019.csv\AB_NYC_2019.csv")

# %%
df.price.describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
min_thresold, max_thresold = df.price.quantile([0.01,0.999])
min_thresold, max_thresold
# Out:
# (30.0, 3000.0)

# %%
df[df.price < min_thresold]
# Out:
#              id                                             name    host_id  \
# 957      375249                  Enjoy Staten Island Hospitality    1887999
# 2675    1428154              Central, Peaceful Semi-Private Room    5912572
# 2860    1620248    Large furnished 2 bedrooms- - 30 days Minimum    2196224
# 3020    1767037               Small Cozy Room Wifi & AC near JFK    9284163
# 3918    2431607                    Bright, Airy Room Share for 2    4973668
# ...         ...                                              ...        ...
# 48486  36280646                     Cable and wfi, L/G included.  272872092
# 48647  36354776    Cozy bedroom in diverse neighborhood near JFK  273393150
# 48832  36450814                         FLATBUSH HANG OUT AND GO  267223765
# 48867  36473044  The place you were dreaming for.(only for guys)  261338177
# 48868  36473253                     Heaven for you(only for guy)  261338177
#
# ...

# %%
df[df.price > max_thresold]
# Out:
#              id                                               name    host_id  \
# 1862     826690                   Sunny, Family-Friendly 2 Bedroom    4289240
# 2698    1448703                Beautiful 1 Bedroom in Nolita/Soho      213266
# 3537    2110145                 UWS 1BR w/backyard + block from CP    2151325
# 3695    2224896                NYC SuperBowl Wk 5 Bdrs River View    11353904
# 3720    2243699                SuperBowl Penthouse Loft 3,000 sqft    1483320
# 3774    2271504                   SUPER BOWL Brooklyn Duplex Apt!!   11598359
# 3788    2281142                 Prime NYC Location for Super Bowl     1427243
# 4345    2919330                   NearWilliamsburg bridge 11211 BK   14908606
# 4376    2952861                               Photography Location    1177497
# 4377    2953058                                      Film Location    1177497
# 6530    4737930                                 Spanish Harlem Apt    1235070
# ...

# %%
df2 = df[(df.price>min_thresold)&(df.price<max_thresold)]
df2.shape
# Out:
# (48183, 16)

# %%
df2.sample(10)
# Out:
#              id                                               name    host_id  \
# 39651  30859271        Comfortable, Quiet, And A Good Night Sleep.  214678935
# 28840  22258326  Gorgeous spacious renovated 1Bed in Hellskitchen!   42304005
# 43934  33956049  Comfortable Private Room with everything you n...  256403429
# 43158  33485978  New to Market, Extended Stay Studio in Park Slope   26989131
# 30895  23922930                                               温馨小屋  179825270
# 31954  24941609   NY’s Highest End Celebrity Building + Balconies!   65562107
# 5881    4286196                  Two bedroom in Prime East Village    6280254
# 18735  14834097       East 63rd street, Studio Serviced Apartment*   22541573
# 10592   8145339                  Chelsea 2-Bedroom Doorman Apt NEW   24430182
# 10054   7718452                 Cosy and Convenient Carroll Garden    3074287
#
#       host_name neighbourhood_group     neighbourhood  latitude  longitude  \
# ...
